# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:\\Users\\KRISHJAI\\OneDrive - Capgemini\\Desktop\\Notes and Ref\\Dataset and database\\Youtube Channel (YT CS-8)\\top-5000-youtube-channels.csv')

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %% [markdown]
# # 1. Display All Rows Except the Last 5 rows Using Head Method

# %%
data.head(-5)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# 3       31180559  22675948293
# 4       32852346  26273668433
# ...          ...          ...
# 4990         --     127185704
# 4991      663114    141933264
# 4992      131766     74304638
# 4993     1586835    371299166
# 4994     1099659    346175699
#
# [4995 rows x 6 columns]

# %% [markdown]
# # 2. Display All Rows Except the First 5 Rows Using Tail Method

# %%
data.tail(-5)
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  \
# 5         6th  A++              Movieclips         30243    17149705
# 6         7th  A++              netd müzik          8500    11373567
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206
# 8         9th  A++         Ryan ToysReview          1140    16082927
# 9        10th  A++             Zee Marathi         74607     2841811
# ...       ...   ...                    ...           ...         ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+             Mastersaint           110     3265735
# 4998  4,999th   B+          Bruce McIntosh          3475       32990
# 4999  5,000th   B+               SehatAQUA           254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...           ...
# 4995    441202795
# 4996    377331722
# 4997    311758426
# 4998     14563764
# 4999     73312511
#
# [4995 rows x 6 columns]

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
print(f'no. of rows: {data.shape[0]}\nno. of columns: {data.shape[1]}')
# Out:
# no. of rows: 5000
# no. of columns: 6

# %% [markdown]
# # 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %% [markdown]
# # 5. Get Overall Statistics About The Dataframe

# %%
pd.options.display.float_format = '{:.2f}'.format
data.describe()
# Out:
#          Video views
# count        5000.00
# mean    398857521.60
# std     754003342.22
# min   -2147283426.00
# 25%     108718281.25
# 50%     354135206.00
# 75%     771646167.50
# max    2143921128.00

# %%
data.describe(include ='all')
# Out:
#         Rank Grade Channel name Video Uploads Subscribers    Video views
# count   5000  5000         5000          5000        5000        5000.00
# unique  5000     6         4993          2286        4612            NaN
# top      1st   B+    Thơ Nguyễn            26         --             NaN
# freq       1  2956            2            17         387            NaN
# mean     NaN   NaN          NaN           NaN         NaN   398857521.60
# std      NaN   NaN          NaN           NaN         NaN   754003342.22
# min      NaN   NaN          NaN           NaN         NaN -2147283426.00
# 25%      NaN   NaN          NaN           NaN         NaN   108718281.25
# 50%      NaN   NaN          NaN           NaN         NaN   354135206.00
# 75%      NaN   NaN          NaN           NaN         NaN   771646167.50
# max      NaN   NaN          NaN           NaN         NaN  2143921128.00

# %% [markdown]
# # 6. Data Cleaning  (Replace '--'  to NaN)

# %%
data.head(20)
# Out:
#     Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0      1      5                      Zee TV          82757     18752951
# 1      2      5                    T-Series          12661     61196302
# 2      3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3      4      5                   SET India          27323     31180559
# 4      5      5                         WWE          36756     32852346
# 5      6      5                  Movieclips          30243     17149705
# 6      7      5                  netd müzik           8500     11373567
# 7      8      5       ABS-CBN Entertainment         100147     12149206
# 8      9      5             Ryan ToysReview           1140     16082927
# 9     10      5                 Zee Marathi          74607      2841811
# 10    11      4             5-Minute Crafts           2085     33492951
# 11    12      4             Canal KondZilla            822     39409726
# 12    13      4            Like Nastya Vlog            150      7662886
# 13    14      4                       Ozuna             50     18824912
# 14    15      4                  Wave Music          16119     15899764
# 15    16      4                 Ch3Thailand          49239     11569723
# 16    17      4             WORLDSTARHIPHOP           4778     15830098
# 18    19      4                     Badabun           3060     23603062
# 19    20      4           WorkpointOfficial          24287     17687229
# 20    21      4                xxxtentacion             48     11593509
#
#     Video views    Avg Views
# 0    -605049889     -7311.16
# 1     304199587     24026.51
# 2    1203370490   3226194.34
# 3    1201111813     43959.73
# 4     503864657     13708.36
# 5    -561774460    -18575.35
# 6   -1871073012   -220126.24
# 7      22740666       227.07
# 8   -1251705735  -1097987.49
# 9   -1703136989    -22828.11
# 10     -2414213     -1157.90
# 11   2111165283   2568327.59
# 12  -1754867365 -11699115.77
# 13    137848633   2756972.66
# 14  -1895722741   -117607.96
# 15    798665683     16220.18
# 16  -1782743413   -373114.99
# 18   1565476757    511593.71
# 19   1137287766     46827.02
# 20   2029279311  42276652.31

# %%
data.replace('--', np.nan,regex=True,inplace=True)

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# 13  14th   A+                        Ozuna            50    18824912
# 14  15th   A+                   Wave Music         16119    15899764
# 15  16th   A+                  Ch3Thailand         49239    11569723
# 16  17th   A+              WORLDSTARHIPHOP          4778    15830098
# 17  18th   A+              Vlad and Nikita            53         NaN
# 18  19th   A+                      Badabun          3060    23603062
# 19  20th   A+            WorkpointOfficial         24287    17687229
#
#     Video views
# 0    -605049889
# 1     304199587
# 2    1203370490
# 3    1201111813
# 4     503864657
# 5    -561774460
# 6   -1871073012
# 7      22740666
# 8   -1251705735
# 9   -1703136989
# 10     -2414213
# 11   2111165283
# 12  -1754867365
# 13    137848633
# 14  -1895722741
# 15    798665683
# 16  -1782743413
# 17   1428274554
# 18   1565476757
# 19   1137287766

# %% [markdown]
# # 7. Check Null Values In The Dataset

# %%
missing_per = data.isnull().sum()*100/len(data)
missing_per
# Out:
# Rank            0.00
# Grade           0.00
# Channel name    0.00
# Video Uploads   0.12
# Subscribers     7.74
# Video views     0.00
# dtype: float64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.dropna(axis=0,inplace=True)

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 8. Data Cleaning [ Rank Column ]

# %%
data['Rank']=data['Rank'].str[:-2]

# %%
data['Rank']=data['Rank'].str.replace(',','')

# %%
data['Rank']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 4995    4996
# 4996    4997
# 4997    4998
# 4998    4999
# 4999    5000
# Name: Rank, Length: 4610, dtype: object

# %% [markdown]
# # 9. Data Cleaning [ Video Uploads & Subscribers ]

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int32
# dtype: object

# %%
convert_dict = {'Rank':int,
                'Subscribers':int,
                'Grade' : int,
                'Video views': int, 
                'Video Uploads':int }

# %%
data = data.astype(convert_dict)
data.dtypes
# Out:
# Rank              int32
# Grade             int32
# Channel name     object
# Video Uploads     int32
# Subscribers       int32
# Video views       int32
# dtype: object

# %% [markdown]
# # 10. Data Cleaning [ Grade Column ]

# %%
data['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
data['Grade']=data['Grade'].map({'A++ ':'5',
                 'A+ ':4, 
                 'A ':3,
                 'A- ':2,
                 'B+ ':1})

# %%
data.dtypes
# Out:
# Rank              int32
# Grade             int32
# Channel name     object
# Video Uploads     int32
# Subscribers       int32
# Video views       int32
# dtype: object

# %% [markdown]
# # 11. Find Average Views For Each Channel

# %%
data['Avg Views'] = data['Video views']/data['Video Uploads']

# %%
data.dtypes
# Out:
# Rank               int32
# Grade              int32
# Channel name      object
# Video Uploads      int32
# Subscribers        int32
# Video views        int32
# Avg Views        float64
# dtype: object

# %%
data
# Out:
#       Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0        1      5                      Zee TV          82757     18752951
# 1        2      5                    T-Series          12661     61196302
# 2        3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3        4      5                   SET India          27323     31180559
# 4        5      5                         WWE          36756     32852346
# ...    ...    ...                         ...            ...          ...
# 4995  4996      1              Uras Benlioğlu            706      2072942
# 4996  4997      1           HI-TECH MUSIC LTD            797      1055091
# 4997  4998      1                 Mastersaint            110      3265735
# 4998  4999      1              Bruce McIntosh           3475        32990
# 4999  5000      1                   SehatAQUA            254        21172
#
#       Video views  Avg Views
# 0      -605049889   -7311.16
# 1       304199587   24026.51
# 2      1203370490 3226194.34
# 3      1201111813   43959.73
# 4       503864657   13708.36
# ...           ...        ...
# 4995    441202795  624933.14
# 4996    377331722  473440.05
# 4997    311758426 2834167.51
# 4998     14563764    4191.01
# 4999     73312511  288631.93
#
# [4610 rows x 7 columns]

# %% [markdown]
# # 12. Find Out Top Five Channels With Maximum Number of Video Uploads

# %%
data['Video Uploads'].sort_values(ascending=False).head().index
# Out:
# Int64Index([3453, 1149, 2223, 323, 2956], dtype='int64')

# %%
i = data['Video Uploads'].sort_values(ascending=False).head().index
data.loc[i]
# Out:
#       Rank  Grade Channel name  Video Uploads  Subscribers  Video views  \
# 3453  3454      1   AP Archive         422326       746325    548619569
# 1149  1150      2     YTN NEWS         355996       820108   1640347646
# 2223  2224      1    SBS Drama         335521      1418619   1565758044
# 323    324      3     GMA News         269065      2599175  -1508018132
# 2956  2957      1          MLB         267649      1434206   1329206392
#
#       Avg Views
# 3453    1299.04
# 1149    4607.77
# 2223    4666.65
# 323    -5604.66
# 2956    4966.23

# %%
data.iloc[i]
# Out:
#       Rank  Grade               Channel name  Video Uploads  Subscribers  \
# 3734  3735      1  Lalitha Audios And Videos            831       618257
# 1241  1242      2                  JFlaMusic            197      9261084
# 2416  2417      1                Astro Arena           5826       175195
# 349    350      3            Goldmines Hindi            292      1719279
# 3206  3207      1                     GugaTV             94       676236
#
#       Video views  Avg Views
# 3734    204810673  246462.90
# 1241   1714185273 8701448.09
# 2416     87255335   14976.89
# 349     544187059 1863654.31
# 3206    120243077 1279181.67

# %%
data.sort_values(by='Video Uploads', ascending=False).head()
# Out:
#       Rank  Grade Channel name  Video Uploads  Subscribers  Video views  \
# 3453  3454      1   AP Archive         422326       746325    548619569
# 1149  1150      2     YTN NEWS         355996       820108   1640347646
# 2223  2224      1    SBS Drama         335521      1418619   1565758044
# 323    324      3     GMA News         269065      2599175  -1508018132
# 2956  2957      1          MLB         267649      1434206   1329206392
#
#       Avg Views
# 3453    1299.04
# 1149    4607.77
# 2223    4666.65
# 323    -5604.66
# 2956    4966.23

# %% [markdown]
# # 13. Find Correlation Matrix

# %%
data.corr()
# Out:
#                Rank  Grade  Video Uploads  Subscribers  Video views  Avg Views
# Rank           1.00  -0.87          -0.07        -0.38         0.01       0.00
# Grade         -0.87   1.00           0.09         0.43        -0.04      -0.01
# Video Uploads -0.07   0.09           1.00         0.01         0.00      -0.04
# Subscribers   -0.38   0.43           0.01         1.00        -0.06      -0.04
# Video views    0.01  -0.04           0.00        -0.06         1.00       0.27
# Avg Views      0.00  -0.01          -0.04        -0.04         0.27       1.00

# %% [markdown]
# # 14.  Which Grade Has A Maximum Number of Video Uploads?

# %%
data.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views  Avg Views
# 0   -605049889   -7311.16
# 1    304199587   24026.51
# 2   1203370490 3226194.34
# 3   1201111813   43959.73
# 4    503864657   13708.36

# %%
sns.barplot(x='Grade',y='Video Uploads', data=data)
# Out:
# <AxesSubplot:xlabel='Grade', ylabel='Video Uploads'>

# %%
sns.barplot(x='Grade',y='Avg Views', data=data)
# Out:
# <AxesSubplot:xlabel='Grade', ylabel='Avg Views'>

# %% [markdown]
# # 15.Which Grade Has The Highest Average Views?

# %% [markdown]
# # 16.  Which Grade Has The Highest Number of Subscribers?

# %% [markdown]
# # 17. Which Grade Has The Highest Video Views?
